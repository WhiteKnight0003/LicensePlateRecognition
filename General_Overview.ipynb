# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - lên roboflow để lấy ảnh

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - định dạng vị trí vật thể trong yolo

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - có nhiều ocr cho phát hiện nhiều loại ngôn ngữ ví dụ như Tesseract OCR
# - ở đây có 2 loại OCR
#     + 1 là truyền thống
#     + 2 là huấn luyện 1 model học sâu cho OCR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - đây là 1 orc với học sâu khá nổi tiếng cho nhiều ngôn ngữ
